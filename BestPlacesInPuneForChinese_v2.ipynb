# %% [markdown]
# <a href="https://colab.research.google.com/github/GB1111/Coursera_Capstone/blob/master/BestPlacesInPuneForChinese_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis

# %%
path = 'https://raw.githubusercontent.com/GB1111/Coursera_Capstone/master/pune_data.csv'
pune_data = pd.read_csv(path)
pune_data.head()
# Out:
#    Postal Code        Place Name County  ... Latitude  Longitude  Accuracy
# 0       410301          Khandala   Pune  ...  18.7589    73.3694         4
# 1       410302  R P T S Khandala   Pune  ...  18.7589    73.3694         1
# 2       410401          Lonavala   Pune  ...  18.7528    73.4057         4
# 3       410401        Kusgaon BK   Pune  ...  18.7528    73.4057         3
# 4       410401    Lonavala Bazar   Pune  ...  18.7528    73.4057         3
#
# [5 rows x 7 columns]

# %%
pune_data.rename(columns={'Place Name':'Neighbourhood'}, inplace = True)
pune_data = pune_data[['Postal Code', 'Community', 'Neighbourhood', 'Latitude', 'Longitude']]
pune_data.shape
# Out:
# (791, 5)

# %%
pune_data.head()
# Out:
#    Postal Code Community     Neighbourhood  Latitude  Longitude
# 0       410301     Maval          Khandala   18.7589    73.3694
# 1       410302     Maval  R P T S Khandala   18.7589    73.3694
# 2       410401     Maval          Lonavala   18.7528    73.4057
# 3       410401     Maval        Kusgaon BK   18.7528    73.4057
# 4       410401     Maval    Lonavala Bazar   18.7528    73.4057

# %%
print('The dataframe has {} communities and {} neighbourhoods.'.format(
        len(pune_data['Community'].unique()),
        pune_data.shape[0]
    )
)
# Out:
# The dataframe has 20 communities and 791 neighbourhoods.

# %%
pune_data.groupby('Community').count()
# Out:
#            Postal Code  Neighbourhood  Latitude  Longitude
# Community
# Ambegaon            43             43        43         43
# Baramati            56             56        56         56
# Bhor                69             69        69         69
# Daund               52             52        52         52
# Haveli              76             76        76         76
# Indapur             50             50        50         50
# Junnar              68             68        68         68
# Khed                68             68        68         68
# Maval               38             38        38         38
# Mawal                5              5         5          5
# Mulashi              1              1         1          1
# Mulshi              29             29        29         29
# Pune                 2              2         2          2
# Pune City          109            109       109        109
# Purandar            53             53        53         53
# Purandhar            2              2         2          2
# Shirur              52             52        52         52
# Shiurur              1              1         1          1
# Velhe               15             15        15         15

# %%
CLIENT_ID = 'NJDMRKKIXGRVKUPRLI4AJDJHDRI5J303R5JNN2FW32HWCSDO' # your Foursquare ID
CLIENT_SECRET = 'QWQYLF3D1BM2T2UOYOVT02KUOS3NANJPU4NIQXU1STJ3ETHS' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: NJDMRKKIXGRVKUPRLI4AJDJHDRI5J303R5JNN2FW32HWCSDO
# CLIENT_SECRET:QWQYLF3D1BM2T2UOYOVT02KUOS3NANJPU4NIQXU1STJ3ETHS

# %%
pune_data.loc[0, 'Neighbourhood']
# Out:
# 'Khandala'

# %%
Neighbourhood_latitude = pune_data.loc[0, 'Latitude'] # neighborhood latitude value
Neighbourhood_longitude = pune_data.loc[0, 'Longitude'] # neighborhood longitude value

Neighbourhood_name = pune_data.loc[0, 'Neighbourhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(Neighbourhood_name, 
                                                               Neighbourhood_latitude, 
                                                               Neighbourhood_longitude))
# Out:
# Latitude and longitude values of Khandala are 18.7589, 73.3694.

# %%
LIMIT = 100
radius = 500 # define radius

 # create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    Neighbourhood_latitude, 
    Neighbourhood_longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=NJDMRKKIXGRVKUPRLI4AJDJHDRI5J303R5JNN2FW32HWCSDO&client_secret=QWQYLF3D1BM2T2UOYOVT02KUOS3NANJPU4NIQXU1STJ3ETHS&v=20180605&ll=18.7589,73.3694&radius=500&limit=100'

# %%
import requests

# %%
results = requests.get(url).json()

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

#import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#                          name             categories        lat        lng
# 0  High Point @ Dukes Retreat              Hotel Bar  18.761639  73.370665
# 1      Dukes Retreat Khandala                  Hotel  18.761514  73.370721
# 2              Shooting point  Outdoors & Recreation  18.758637  73.373100
# 3             Velvett Country                 Resort  18.755733  73.367764

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 4 venues were returned by Foursquare.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood', 
                  'Neighbourhood Latitude', 
                  'Neighbourhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
pune_venues = getNearbyVenues(names=pune_data['Neighbourhood'],
                                   latitudes=pune_data['Latitude'],
                                   longitudes=pune_data['Longitude']
                                 )
print(pune_venues.shape)
# Out:
# Khandala
# R P T S Khandala
# Lonavala
# Kusgaon BK
# Lonavala Bazar
# Ambavane
# Ins Shivaji Lonavale
# Kurwande
# Kaivalyadham
# Karanjgaon
# Kamshet
# Karunj
# Malawali
# Karla
# Takave KH
# Vehergaon
# Nane
# Pawananagar
# Shivali
# Bhose
# Chakan
# Mahalunge Ingale
# Vasuli
# Waki BK
# Ambethan
# Vadgaon Ghenanad
# Khalumbre
# Shive
# Rase
# Pimpalgaon Tarfe Chakan
# Kuruli
# Koyali
# Nighoje
# Kalus
# Gadad
# Bahul
# Rajur
# Parunde
# Junnar
# Tambe
# Devale
# Inglun
# Khanapur
# Vadaj
# Anjanavale
# Kusur
# Khangaon
# Amboli
# Aptale
# Yenere
# Khamgaon
# Khadkumbe(Exptl)
# Ballalwadi
# Manikdoh
# Chavand
# Nimgiri
# Godre
# Nirgude
# Utchil
# Manchar
# Landewadi
# Chandoli BK
# Vadgaon Kashimbeg
# Pimpalgaon Mahalunge
# Narodi
# Ozar
# Khodad
# Yedgaon
# Pimparkhed
# Pargaon Tarfe Ala
# Ranjani
# Valati
# Narayangaon
# Nimgaon Sava
# Khamundi
# Pimpri Pendhar
# Jambhut
# Hivare BK
# Amboli
# Vaphgaon
# Pimpri BK
# Rajgurunagar
# Palu
# Donda
# Nimgaon Khed
# Chinchoshi
# Pait
# Yeniye BK
# Kurkundi
# Varude
# Kude BK
# Sandbhorwadi(Exptl)
# Kiwale
# Kanhersar
# Retwadi
# Shiroli
# Gulani
# Ghotawadi
# Dawadi
# Talegaon Dabhade
# Dhamane
# Urse
# Chandkhed
# Adhale BK
# Bebedhol
# Ordanance Dep Talegaon Dabhade
# Kasarsai
# Shiavane
# Ambi
# Umbre Navlakh
# Vishnupuri
# Talegaon G H
# Ambale
# Induri
# Varale
# Dhamani
# Bhimashankar
# Phulawade
# Pokhari
# Asane
# Taleghar
# Adivare
# Rajpur
# Jambhori
# Tirpad
# Kondhwal
# Dimbhe Colony
# Kushire BK
# Gohe BK
# Bhorghar
# Vadgaon Peer
# Loni Dhamani
# Savindane
# Shiroli B K
# Kuran
# Peth (Pune)
# Karegaon
# Thugaon
# Kurwandi
# Pargaon Tarfe Khed
# Kadadhe
# Chas (Pune)
# Bibi
# Bhodani
# Lakhewadi
# Shetphal Haveli
# Pimpri BK
# Bhavaninagar (Pune)
# Sapkalwadi
# Bori
# Sansar
# Tavshi
# Belawadi
# Kuravali
# Kazad
# Katyachiwadi
# Dhekalwadi
# Udhat
# Kalas
# Rajegaon
# Khanote
# Bhigwan R S
# Watluj
# Indapur
# Vadapuri
# Hingangaon
# Kalthan No 1
# Kalashi
# Bijawadi
# Indapur Bazar
# Pandhare
# Manappawasti
# Loni Bhapkar
# Kambaleshwar
# Dhakale
# Mudhale
# Shirasane
# Kalamb
# Lasurna
# Nimsakhar
# Shirsatwadi
# Rangaon
# Anthurne
# Shelgaon
# Walchandnagar
# Redni
# Nirwangi
# Khorochi
# Malegaon IRR Colony
# Malegaon BK
# Shivnagar
# Khandaj
# Kati
# Ghotondi
# Nimgaon Ketki
# Varkute KH
# Vyahali
# Chincholi
# Ravangaon
# Nirgude
# Bhigwan
# Madanwadi
# Malad
# Parwadi
# Khadaki
# Shetfalgade
# Palasdeo
# Nhavi
# Loni Deokar
# Agoti
# Dalaj
# Saval
# MIDC Baramati
# Katfal
# Girim
# Daund
# Gopalwadi
# Malthan
# Alegaon
# Deulgaonraja
# Beam Wirelee Station
# S R P F Daund
# Boribyal
# Shirapur
# Nanvij
# Kalewadi
# Hingniberdi
# Kurkumbh
# MIDC Kurkumbh
# (906, 7)

# %%
pune_venues.shape
# Out:
# (906, 7)

# %%
pune_venues.head()
# Out:
#       Neighbourhood  ...         Venue Category
# 0          Khandala  ...              Hotel Bar
# 1          Khandala  ...                  Hotel
# 2          Khandala  ...  Outdoors & Recreation
# 3          Khandala  ...                 Resort
# 4  R P T S Khandala  ...              Hotel Bar
#
# [5 rows x 7 columns]

# %%
pune_venues.groupby('Neighbourhood').count()
# Out:
#                 Neighbourhood Latitude  ...  Venue Category
# Neighbourhood                           ...
# 9 DRD                               36  ...              36
# A.R. Shala                          16  ...              16
# Adhale BK                            4  ...               4
# Airport (Pune)                       5  ...               5
# Akurdi                               4  ...               4
# ...                                ...  ...             ...
# Waki                                 2  ...               2
# Warje                                6  ...               6
# Yavat                                1  ...               1
# Yerwada                              3  ...               3
# Yerwada T.S.                         3  ...               3
#
# [177 rows x 6 columns]

# %%
print('There are {} uniques categories.'.format(len(pune_venues['Venue Category'].unique())))
# Out:
# There are 83 uniques categories.

# %% [markdown]
# **Analyze Each Neighborhood**

# %%
# one hot encoding
pune_onehot = pd.get_dummies(pune_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighbourhood column back to dataframe
pune_onehot['Neighbourhood'] = pune_venues['Neighbourhood'] 

# move neighbourhood column to the first column
fixed_columns = [pune_onehot.columns[-1]] + list(pune_onehot.columns[:-1])
pune_onehot = pune_onehot[fixed_columns]

pune_onehot.head()
# Out:
#       Neighbourhood  ATM  ...  Train Station  Vegetarian / Vegan Restaurant
# 0          Khandala    0  ...              0                              0
# 1          Khandala    0  ...              0                              0
# 2          Khandala    0  ...              0                              0
# 3          Khandala    0  ...              0                              0
# 4  R P T S Khandala    0  ...              0                              0
#
# [5 rows x 84 columns]

# %%
pune_onehot.shape
# Out:
# (906, 84)

# %%
pune_grouped = pune_onehot.groupby('Neighbourhood').mean().reset_index()
pune_grouped
# Out:
#       Neighbourhood  ATM  ...  Train Station  Vegetarian / Vegan Restaurant
# 0             9 DRD  0.0  ...            0.0                            0.0
# 1        A.R. Shala  0.0  ...            0.0                            0.0
# 2         Adhale BK  0.0  ...            0.5                            0.0
# 3    Airport (Pune)  0.0  ...            0.0                            0.0
# 4            Akurdi  0.0  ...            0.0                            0.0
# ..              ...  ...  ...            ...                            ...
# 172            Waki  0.0  ...            0.0                            0.0
# 173           Warje  0.0  ...            0.0                            0.0
# 174           Yavat  0.0  ...            0.0                            0.0
# 175         Yerwada  0.0  ...            0.0                            0.0
# 176    Yerwada T.S.  0.0  ...            0.0                            0.0
#
# [177 rows x 84 columns]

# %%
pune_grouped.shape
# Out:
# (177, 84)

# %%
chinese_grouped = pune_grouped[['Neighbourhood', 'Chinese Restaurant']]
chinese_grouped.head()
# Out:
#     Neighbourhood  Chinese Restaurant
# 0           9 DRD            0.055556
# 1      A.R. Shala            0.062500
# 2       Adhale BK            0.000000
# 3  Airport (Pune)            0.000000
# 4          Akurdi            0.000000

# %%
chinese_grouped = chinese_grouped.join(pune_data.set_index("Neighbourhood"), on="Neighbourhood")
chinese_grouped.head()
# Out:
#     Neighbourhood  Chinese Restaurant  ...  Latitude Longitude
# 0           9 DRD            0.055556  ...   18.5685   73.9158
# 1      A.R. Shala            0.062500  ...   18.5148   73.8358
# 2       Adhale BK            0.000000  ...   18.7350   73.6756
# 3  Airport (Pune)            0.000000  ...   18.5333   73.8667
# 4          Akurdi            0.000000  ...   18.6532   73.7896
#
# [5 rows x 6 columns]

# %%
chinese_grouped.shape
# Out:
# (182, 6)

# %%
chinese_grouped = chinese_grouped[['Neighbourhood', 'Community', 'Chinese Restaurant']]
chinese_grouped.head()
# Out:
#     Neighbourhood  Community  Chinese Restaurant
# 0           9 DRD  Pune City            0.055556
# 1      A.R. Shala  Pune City            0.062500
# 2       Adhale BK      Maval            0.000000
# 3  Airport (Pune)  Pune City            0.000000
# 4          Akurdi  Pune City            0.000000

# %% [markdown]
# **Cluster Neighborhoods**

# %%
# set number of clusters
kclusters = 3

#chinese_grouped_clustering = chinese_grouped.drop('Neighbourhood', 'Community', 2)
chinese_grouped_clustering = chinese_grouped[['Chinese Restaurant']]
# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(chinese_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([2, 2, 0, 0, 0, 0, 0, 0, 0, 0], dtype=int32)

# %%
# create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.
pune_merged = chinese_grouped.copy()

# add clustering labels
pune_merged["Cluster Labels"] = kmeans.labels_

# %%
pune_merged.head()
# Out:
#     Neighbourhood  Community  Chinese Restaurant  Cluster Labels
# 0           9 DRD  Pune City            0.055556               2
# 1      A.R. Shala  Pune City            0.062500               2
# 2       Adhale BK      Maval            0.000000               0
# 3  Airport (Pune)  Pune City            0.000000               0
# 4          Akurdi  Pune City            0.000000               0

# %%
# merge pune_grouped with pune_venues to add latitude/longitude for each neighborhood
pune_merged = pune_merged.join(pune_venues.set_index("Neighbourhood"), on="Neighbourhood")

# %%
print(pune_merged.shape)
pune_merged.head()
# Out:
# (944, 10)
#   Neighbourhood  Community  ...  Venue Longitude                   Venue Category
# 0         9 DRD  Pune City  ...        73.917748                   Ice Cream Shop
# 0         9 DRD  Pune City  ...        73.914766                      Coffee Shop
# 0         9 DRD  Pune City  ...        73.918158                        Juice Bar
# 0         9 DRD  Pune City  ...        73.918249                      Coffee Shop
# 0         9 DRD  Pune City  ...        73.913116  Southern / Soul Food Restaurant
#
# [5 rows x 10 columns]

# %%
# sort the results by Cluster Labels
print(pune_merged.shape)
pune_merged.sort_values(["Cluster Labels"], inplace=True)
pune_merged
# Out:
# (944, 10)
#       Neighbourhood  Community  ...  Venue Longitude               Venue Category
# 77       Kusgaon BK      Maval  ...        73.407739                        Trail
# 92     Model Colony  Pune City  ...        73.878514                  Pizza Place
# 93            Moshi     Haveli  ...        73.896888                        River
# 94          Mundhva     Haveli  ...        73.933589  Eastern European Restaurant
# 94          Mundhva     Haveli  ...        73.932879                    Hotel Bar
# ..              ...        ...  ...              ...                          ...
# 45   Film Institute  Pune City  ...        73.831985                        Track
# 1        A.R. Shala  Pune City  ...        73.831985                        Track
# 1        A.R. Shala  Pune City  ...        73.837168            Mobile Phone Shop
# 163   Vadgaon Sheri  Pune City  ...        73.918383                         Café
# 0             9 DRD  Pune City  ...        73.917748               Ice Cream Shop
#
# [944 rows x 10 columns]

# %%
grouped = pune_merged.groupby('Cluster Labels')['Chinese Restaurant'].count()
grouped.head()
# Out:
# Cluster Labels
# 0    713
# 1     39
# 2    192
# Name: Chinese Restaurant, dtype: int64

# %%
# !pip install geocoder
# Out:
# Collecting geocoder
#   Downloading https://files.pythonhosted.org/packages/4f/6b/13166c909ad2f2d76b929a4227c952630ebaf0d729f6317eb09cbceccbab/geocoder-1.38.1-py2.py3-none-any.whl (98kB)
#      |████████████████████████████████| 102kB 2.3MB/s
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from geocoder) (7.1.2)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from geocoder) (0.16.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from geocoder) (2.23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from geocoder) (1.12.0)
# Collecting ratelim
#   Downloading https://files.pythonhosted.org/packages/f2/98/7e6d147fd16a10a5f821db6e25f192265d6ecca3d82957a4fdd592cad49c/ratelim-0.1.6-py2.py3-none-any.whl
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->geocoder) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->geocoder) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->geocoder) (2020.4.5.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from ratelim->geocoder) (4.4.2)
# Installing collected packages: ratelim, geocoder
# Successfully installed geocoder-1.38.1 ratelim-0.1.6

# %%
import geocoder

# %%
address = 'Pune, IN'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Pune are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Pune are 18.521428, 73.8544541.

# %%
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(pune_merged['Neighbourhood Latitude'], pune_merged['Neighbourhood Longitude'], pune_merged['Neighbourhood'], pune_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# save the map as JPG file
map_clusters.save('map_clusters.jpg')

# %% [markdown]
# **Examine Clusters**

# %%
#Cluster 0
pune_merged.loc[pune_merged['Cluster Labels'] == 0]
# Out:
#    Neighbourhood  Community  ...  Venue Longitude               Venue Category
# 77    Kusgaon BK      Maval  ...        73.407739                        Trail
# 92  Model Colony  Pune City  ...        73.878514                  Pizza Place
# 93         Moshi     Haveli  ...        73.896888                        River
# 94       Mundhva     Haveli  ...        73.933589  Eastern European Restaurant
# 94       Mundhva     Haveli  ...        73.932879                    Hotel Bar
# ..           ...        ...  ...              ...                          ...
# 63   Karanjawane     Shirur  ...        74.241382            Indian Restaurant
# 63   Karanjawane       Bhor  ...        74.242546                  Coffee Shop
# 64         Karla      Maval  ...        73.477226                   Toll Plaza
# 64         Karla      Maval  ...        73.478870                         Farm
# 63   Karanjawane       Bhor  ...        74.241382            Indian Restaurant
#
# [713 rows x 10 columns]

# %%
#Cluster 1
pune_merged.loc[pune_merged['Cluster Labels'] == 1]
# Out:
#     Neighbourhood  Community  ...  Venue Longitude        Venue Category
# 11       Armament  Pune City  ...        73.782387          Dessert Shop
# 152           Sus     Haveli  ...        73.782387          Dessert Shop
# 152           Sus     Haveli  ...        73.782098    Chinese Restaurant
# 152           Sus     Haveli  ...        73.782144           Snack Place
# 152           Sus     Haveli  ...        73.782216    Seafood Restaurant
# 152           Sus     Haveli  ...        73.781944                  Café
# 152           Sus     Haveli  ...        73.782000           Pizza Place
# 152           Sus     Haveli  ...        73.782179                  Café
# 152           Sus     Haveli  ...        73.782405  Fast Food Restaurant
# 152           Sus     Haveli  ...        73.782382                  Café
# 152           Sus     Haveli  ...        73.781699            Restaurant
# 152           Sus     Haveli  ...        73.781659                Office
# 152           Sus     Haveli  ...        73.782509        Ice Cream Shop
# 152           Sus     Haveli  ...        73.778416        Shop & Service
# 11       Armament  Pune City  ...        73.782098    Chinese Restaurant
# 11       Armament  Pune City  ...        73.781944                  Café
# 11       Armament  Pune City  ...        73.782216    Seafood Restaurant
# 11       Armament  Pune City  ...        73.782144           Snack Place
# 16        Bavdhan     Haveli  ...        73.778416        Shop & Service
# 16        Bavdhan     Haveli  ...        73.782509        Ice Cream Shop
# 16        Bavdhan     Haveli  ...        73.781659                Office
# 16        Bavdhan     Haveli  ...        73.781699            Restaurant
# 16        Bavdhan     Haveli  ...        73.782382                  Café
# 16        Bavdhan     Haveli  ...        73.782179                  Café
# 16        Bavdhan     Haveli  ...        73.782000           Pizza Place
# 16        Bavdhan     Haveli  ...        73.781944                  Café
# 16        Bavdhan     Haveli  ...        73.782216    Seafood Restaurant
# 16        Bavdhan     Haveli  ...        73.782144           Snack Place
# 16        Bavdhan     Haveli  ...        73.782098    Chinese Restaurant
# 16        Bavdhan     Haveli  ...        73.782387          Dessert Shop
# 16        Bavdhan     Haveli  ...        73.782405  Fast Food Restaurant
# 11       Armament  Pune City  ...        73.782382                  Café
# 11       Armament  Pune City  ...        73.778416        Shop & Service
# 11       Armament  Pune City  ...        73.782509        Ice Cream Shop
# 11       Armament  Pune City  ...        73.781659                Office
# 11       Armament  Pune City  ...        73.781699            Restaurant
# 11       Armament  Pune City  ...        73.782405  Fast Food Restaurant
# 11       Armament  Pune City  ...        73.782179                  Café
# 11       Armament  Pune City  ...        73.782000           Pizza Place
#
# [39 rows x 10 columns]

# %%
#Cluster 2
pune_merged.loc[pune_merged['Cluster Labels'] == 2]
# Out:
#       Neighbourhood  ...                   Venue Category
# 0             9 DRD  ...                      Pizza Place
# 0             9 DRD  ...                Indian Restaurant
# 0             9 DRD  ...  Southern / Soul Food Restaurant
# 0             9 DRD  ...                      Coffee Shop
# 0             9 DRD  ...                             Café
# ..              ...  ...                              ...
# 45   Film Institute  ...                            Track
# 1        A.R. Shala  ...                            Track
# 1        A.R. Shala  ...                Mobile Phone Shop
# 163   Vadgaon Sheri  ...                             Café
# 0             9 DRD  ...                   Ice Cream Shop
#
# [192 rows x 10 columns]

# %% [markdown]
# **Observations**

# %% [markdown]
# Most of the Chinese restaurants are in Cluster 1 which is around Sus, Bavdhan
# and Armament areas and lowest (close to zero) in Cluster 0 areas which are Lonavala, Narayan Peth, Yerwada areas. Also, there are good opportunities to open near Vadgaon Sheri, Film Institute as the competition seems to be low. Looking at nearby venues, it seems Cluster 2 might be a good location as there are not a lot of Chinese restaurants in these areas. Therefore, this project recommends the entrepreneur to open a Chinese restaurant in these locations with little to no competition.
